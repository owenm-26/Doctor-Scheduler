# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data_path = Path('data/excercise-recognition')

labels = pd.read_csv(data_path / 'labels.csv')
landmarks = pd.read_csv(data_path / 'landmarks.csv')
xyz_distances = pd.read_csv(data_path / 'xyz_distances.csv')
angles = pd.read_csv(data_path / 'angles.csv')
distances = pd.read_csv(data_path / '3d_distances.csv')

# %%
labels[labels['pose'] == 'squats_down']
# Out:
#       pose_id         pose
# 1106     1106  squats_down
# 1107     1107  squats_down
# 1108     1108  squats_down
# 1109     1109  squats_down
# 1110     1110  squats_down
# ...       ...          ...
# 1228     1228  squats_down
# 1229     1229  squats_down
# 1230     1230  squats_down
# 1231     1231  squats_down
# 1232     1232  squats_down
#
# [127 rows x 2 columns]

# %%
landmarks[landmarks['pose_id'] >= 1106]
# Out:
#       pose_id     x_nose     y_nose      z_nose  x_left_eye_inner  \
# 1106     1106 -18.060345 -57.048756  -23.424711        -17.053493
# 1107     1107 -21.053514 -54.721770  -23.086070        -20.256176
# 1108     1108  -9.066656 -60.404633  -23.105520         -7.069842
# 1109     1109  22.500174 -51.544360  -18.086287         24.769554
# 1110     1110  25.742037 -61.347656 -140.244190         25.569183
# ...       ...        ...        ...         ...               ...
# 1367     1367  -2.802355 -52.953636   33.939075         -2.539375
# 1368     1368  -3.224722 -53.435062   24.807423         -3.021559
# 1369     1369  -5.246736 -51.167410   42.242527         -4.634136
# 1370     1370  -9.454565 -50.395477   48.190674         -9.892803
# 1371     1371  -7.642476 -51.768620   45.853340         -8.386562
#
#       y_left_eye_inner  z_left_eye_inner  x_left_eye  y_left_eye  z_left_eye  \
# 1106        -59.646140        -26.981739  -16.859050  -59.636967  -26.986880
# ...

# %%
plt.subplot(331)
plt.scatter(landmarks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.subplot(331)
# ----> 2 plt.scatter(landmarks)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
distances
# Out:
#       pose_id  left_shoulder_left_wrist  right_shoulder_right_wrist  \
# 0           0                 38.423300                   39.855762
# 1           1                 65.631510                   65.847110
# 2           2                 69.661674                   69.360990
# 3           3                 52.437600                   55.870330
# 4           4                 30.867628                   43.872227
# ...       ...                       ...                         ...
# 1367     1367                 40.593422                   53.249480
# 1368     1368                 39.974773                   47.849680
# 1369     1369                 45.298250                   56.949980
# 1370     1370                 45.043040                   29.450825
# 1371     1371                 32.080090                   55.098830
#
#       left_hip_left_ankle  right_hip_right_ankle  left_hip_left_wrist  \
# 0               62.640720              57.871964            15.052525
# ...

# %%
labels
# Out:
#       pose_id                pose
# 0           0  jumping_jacks_down
# 1           1  jumping_jacks_down
# 2           2  jumping_jacks_down
# 3           3  jumping_jacks_down
# 4           4  jumping_jacks_down
# ...       ...                 ...
# 1367     1367           squats_up
# 1368     1368           squats_up
# 1369     1369           squats_up
# 1370     1370           squats_up
# 1371     1371           squats_up
#
# [1372 rows x 2 columns]

# %%
landmarks
# Out:
#       pose_id    x_nose     y_nose      z_nose  x_left_eye_inner  \
# 0           0 -5.889507 -57.637520  -45.019750         -4.656085
# 1           1 -4.255504 -62.935925 -128.907500         -2.977403
# 2           2 -2.878917 -61.709988 -137.453340         -1.619050
# 3           3 -4.242575 -60.371220 -135.094830         -3.118133
# 4           4 -0.805543 -56.178570  -41.124413         -0.055174
# ...       ...       ...        ...         ...               ...
# 1367     1367 -2.802355 -52.953636   33.939075         -2.539375
# 1368     1368 -3.224722 -53.435062   24.807423         -3.021559
# 1369     1369 -5.246736 -51.167410   42.242527         -4.634136
# 1370     1370 -9.454565 -50.395477   48.190674         -9.892803
# 1371     1371 -7.642476 -51.768620   45.853340         -8.386562
#
#       y_left_eye_inner  z_left_eye_inner  x_left_eye  y_left_eye  z_left_eye  \
# 0           -62.832863        -44.571823   -3.302626  -63.386856  -44.567863
# ...

# %%
landmarks
# Out:
#       pose_id    x_nose     y_nose      z_nose  x_left_eye_inner  \
# 0           0 -5.889507 -57.637520  -45.019750         -4.656085
# 1           1 -4.255504 -62.935925 -128.907500         -2.977403
# 2           2 -2.878917 -61.709988 -137.453340         -1.619050
# 3           3 -4.242575 -60.371220 -135.094830         -3.118133
# 4           4 -0.805543 -56.178570  -41.124413         -0.055174
# ...       ...       ...        ...         ...               ...
# 1367     1367 -2.802355 -52.953636   33.939075         -2.539375
# 1368     1368 -3.224722 -53.435062   24.807423         -3.021559
# 1369     1369 -5.246736 -51.167410   42.242527         -4.634136
# 1370     1370 -9.454565 -50.395477   48.190674         -9.892803
# 1371     1371 -7.642476 -51.768620   45.853340         -8.386562
#
#       y_left_eye_inner  z_left_eye_inner  x_left_eye  y_left_eye  z_left_eye  \
# 0           -62.832863        -44.571823   -3.302626  -63.386856  -44.567863
# ...

# %%
pd.concat([labels, landmarks], axis=1).to_csv(data_path / 'combined_dataset.csv', index=False)

# %%
labels
# Out:
#       pose_id                pose
# 0           0  jumping_jacks_down
# 1           1  jumping_jacks_down
# 2           2  jumping_jacks_down
# 3           3  jumping_jacks_down
# 4           4  jumping_jacks_down
# ...       ...                 ...
# 1367     1367           squats_up
# 1368     1368           squats_up
# 1369     1369           squats_up
# 1370     1370           squats_up
# 1371     1371           squats_up
#
# [1372 rows x 2 columns]

# %%
landmarks['pose_id']

# %%
pd.concat([labels, landmarks], axis=1)
# Out:
#       pose_id                pose  pose_id    x_nose     y_nose      z_nose  \
# 0           0  jumping_jacks_down        0 -5.889507 -57.637520  -45.019750
# 1           1  jumping_jacks_down        1 -4.255504 -62.935925 -128.907500
# 2           2  jumping_jacks_down        2 -2.878917 -61.709988 -137.453340
# 3           3  jumping_jacks_down        3 -4.242575 -60.371220 -135.094830
# 4           4  jumping_jacks_down        4 -0.805543 -56.178570  -41.124413
# ...       ...                 ...      ...       ...        ...         ...
# 1367     1367           squats_up     1367 -2.802355 -52.953636   33.939075
# 1368     1368           squats_up     1368 -3.224722 -53.435062   24.807423
# 1369     1369           squats_up     1369 -5.246736 -51.167410   42.242527
# 1370     1370           squats_up     1370 -9.454565 -50.395477   48.190674
# 1371     1371           squats_up     1371 -7.642476 -51.768620   45.853340
#
# ...

# %%
for i, row in pd.concat([labels, landmarks], axis=1).iterrows():
    print(row['pose'])
    print(row.iloc[3:].to_numpy())
    break
# Out:
# jumping_jacks_down
# [-5.889507 -57.63752 -45.01975 -4.6560855 -62.832863 -44.571823 -3.3026257
#  -63.386856 -44.567863 -2.032406 -63.872166 -44.56217 -7.365534 -61.547394
#  -43.22219 -8.094638 -61.181343 -43.219574 -8.7948885 -60.837234
#  -43.221565 0.3203408 -63.05772 -35.62575 -8.877375 -58.75578 -29.455366
#  -3.112062 -54.17046 -41.242752 -6.512476 -53.172638 -39.353046 7.621102
#  -41.408276 -24.472181 -9.392822 -38.572105 -23.24771 9.6447 -19.461535
#  -11.06757 -11.83377 -16.390108 -13.978561 10.260753 -4.8750734 -12.865825
#  -11.489133 1.0886645 -19.914438 10.423702 2.853016 -14.993233 -11.643494
#  7.434713 -22.953787 9.608641 2.667237 -17.855345 -10.3145075 6.941773
#  -25.846296 8.956856 0.19223653 -13.945213 -9.87707 4.980656 -21.360184
#  4.530677 -0.7698827 0.43425673 -4.5306797 0.7698827 -0.43425673 5.4820313
#  22.849077 5.814251 -3.823916 21.40506 7.528501 5.2401614 33.9869
#  52.543015 -1.3592856 34.199524 46.69923 3.6150978 27.651157 56.852562
# ...

# %%
pd.read_csv(data_path / 'combined_dataset.csv')
# Out:
#       pose_id                pose  pose_id.1    x_nose     y_nose      z_nose  \
# 0           0  jumping_jacks_down          0 -5.889507 -57.637520  -45.019750
# 1           1  jumping_jacks_down          1 -4.255504 -62.935925 -128.907500
# 2           2  jumping_jacks_down          2 -2.878917 -61.709988 -137.453340
# 3           3  jumping_jacks_down          3 -4.242575 -60.371220 -135.094830
# 4           4  jumping_jacks_down          4 -0.805543 -56.178570  -41.124413
# ...       ...                 ...        ...       ...        ...         ...
# 1580     1580              Clamps       1580  0.470549   0.418179   -0.331617
# 1581     1581              Clamps       1581  0.470495   0.417263   -0.319352
# 1582     1582              Clamps       1582  0.470004   0.416179   -0.283997
# 1583     1583              Clamps       1583  0.469970   0.415643   -0.236189
# 1584     1584              Clamps       1584  0.470241   0.415700   -0.233019
#
# ...
